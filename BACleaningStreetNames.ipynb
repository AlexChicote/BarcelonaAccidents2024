# %%
import pandas as pd
from rapidfuzz import fuzz, process
import python_files.functions_barcelona as fb

import time
import folium
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderRateLimited

# %%
##Functions

def safe_reverse_geocode(lat, lon):
    try:
        # Increase timeout to 10 seconds instead of 1
        location = geolocator.reverse((lat, lon), timeout=10)
        
        return location
    except GeocoderTimedOut:
        print("Server was too slow, trying again...")
        time.sleep(2)
        return safe_reverse_geocode(lat, lon)

# %%
year = 2025
geolocator = Nominatim(user_agent="BarcelonaAccidents Analysis")
accidents = pd.read_csv(fb.FILES_PATH / 'accidents_weather2025.csv')

# %%
# 1. Load the Open Data BCN master registry and accidents

bcn_streets = pd.read_csv(fb.FILES_PATH /'carrerer.csv')
accidents = pd.read_csv(fb.FILES_PATH / f'accidents_weather2025.csv')
accidents['street_name'] = accidents['street_name'].str.lower().str.strip()
# Requires columns: codi_via, nom_oficial, nom_curt

# Lowercase and clean names for robust dictionary lookup
bcn_streets['clean_official'] = bcn_streets['nom_oficial'].str.lower().str.strip()
bcn_streets['clean_short'] = bcn_streets['nom_curt'].str.lower().str.strip()
official_lookup = dict(zip(bcn_streets['clean_official'], zip(bcn_streets['codi_via'], bcn_streets['nom_oficial'])))
short_lookup = dict(zip(bcn_streets['clean_short'], zip(bcn_streets['codi_via'], bcn_streets['nom_oficial'])))

# 2. Extract a list of all clean official names for Fuzzy Matching fallback
all_official_names = list(official_lookup.keys())
all_short_names = list(short_lookup.keys())

my_df =accidents[['street_name']].copy()
my_df.columns = ['raw_location']

# Helper function to find a code via exact lookup or rapidfuzz fallback
def get_street_details_hierarchical(street_name, confidence_cutoff=75.0):
    if not street_name:
        return None, None, 0
    
    st_clean = street_name.lower().strip()
    
    # ---- TIER 1: Exact Match on Short Names ----
    if st_clean in short_lookup:
        code, official_name = short_lookup[st_clean]
        return int(code), official_name, 100.0

    # ---- TIER 2: Exact Match on Official Names ----
    if st_clean in official_lookup:
        code, official_name = official_lookup[st_clean]
        return int(code), official_name, 100.0

    # ---- TIER 3: Fuzzy Match on Short Names (Handles short typos) ----
    match_short = process.extractOne(st_clean, all_short_names, scorer=fuzz.token_sort_ratio, score_cutoff=confidence_cutoff)
    if match_short:
        matched_key = match_short[0]
        score = match_short[1]
        code, official_name = short_lookup[matched_key]
        return int(code), official_name, float(score)

    # ---- TIER 4: Fuzzy Match on Official Names (Handles long typos) ----
    match_official = process.extractOne(st_clean, all_official_names, scorer=fuzz.token_sort_ratio, score_cutoff=confidence_cutoff)
    if match_official:
        matched_key = match_official[0]
        score =match_official[1]
        code, official_name = official_lookup[matched_key]
        
        return int(code), official_name, float(score)
        
    return None, None, 0.0
    
def parse_and_assign_codes(address_str):
    if pd.isna(address_str):
        return pd.Series([None, None, None, None, "Single Street", "Empty Row", 0.0])
    
    cleaned = str(address_str).lower()
    for prefix in ["carrer de ", "carrer del ", "avinguda de ", "av. ", "passeig de ", "pg. "]:
        cleaned = cleaned.replace(prefix, "")

    delimiters = ['/', ' amb ', ' con ', '&']
    split_delimiter = None
    for d in delimiters:
        if d in cleaned:
            split_delimiter = d
            break
    # Crossroads Parsing
    if split_delimiter:
        parts = cleaned.split(split_delimiter)
        st1, st2 = parts[0].strip(), parts[1].strip()
        
        code1, name1, score1 = get_street_details_hierarchical(st1)
        code2, name2, score2 = get_street_details_hierarchical(st2)

        if code1 and code2:
            avg_score = (score1 + score2) / 2
            return pd.Series([code1, code2, name1, name2, "Crossroad", "Successfully Matched", avg_score])
        else:
            return pd.Series([code1, code2, name1, name2, "Crossroad", "Error: Unmatched segments", min(score1, score2)])

    else:
        code1, name1, score1 = get_street_details_hierarchical(cleaned.strip())
        if code1:
            return pd.Series([code1, None, name1, None, "Single Street", f"Matched ({name1})", score1])
        else:
            return pd.Series([None, None, None, None, "Single Street", "Error: Unmatched", 0.0])
        
processed_data = my_df['raw_location'].apply(parse_and_assign_codes)

new_cols = ['code_via_1', 'code_via_2', 'official_name_1', 
            'official_name_2', 'location_type', 'match_status', 
            'confidence_score']
processed_data.columns = new_cols
final_df = pd.concat([my_df['raw_location'], processed_data],axis =1)


# Formatting output display view
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

assert final_df.confidence_score.mean() >90, "Confidence Score too low"
print("CONFIDENCE SCORE: ", final_df.confidence_score.mean() )
if final_df[final_df.match_status.str.startswith('Error: Unmatched')].shape[0] == 0:
    print('SHAPE', final_df.shape)
    final_df.drop_duplicates().to_csv(fb.FILES_PATH / f'cleaned_streets_{year}.csv',index=False)
    print('SHAPE AFTER', final_df.drop_duplicates().shape)
else:
    print(f'Check this issue {final_df[final_df.match_status.str.startswith("Error: Unmatched")].shape[0]}')
# Out:
# CONFIDENCE SCORE:  93.37605322411078
# SHAPE (141338, 8)
# SHAPE AFTER (8672, 8)

# %%
##Fixing desconegut District
unique_districts = accidents.district.unique().tolist()
try:
    unique_districts.remove('Desconegut')
except:
    print("DONE FIXING DISTRICTS")
unique_districts = [dis.lower() for dis in unique_districts]
unknown_districts = accidents[accidents.district == 'Desconegut']
print(unknown_districts.shape)
to_check = []

for idx, row in unknown_districts.head(20).iterrows():
    print(idx, row['lat'],row['lon'])
    result = safe_reverse_geocode(row['lat'], row['lon'])
    # print(row['street_name'].upper(), result.raw['address'])
    if 'suburb'  in result.raw['address']:
        print("SUBURB: ",result.raw['address']['suburb'])
        accidents.loc[idx, 'district'] = result.raw['address']['suburb'].strip()
    elif 'town' in  result.raw['address']:
        print("TOWN: ",result.raw['address']['town'])
        accidents.loc[idx, 'district'] = result.raw['address']['town'].strip()
    elif 'city' in result.raw['address']:
        print("CITY: ",result.raw['address']['city'])
        accidents.loc[idx, 'district'] = result.raw['address']['city'].strip()
    else:
        print("ALARMMMMMMMMMMMMMM",idx)
        to_check.append((idx,result.raw['address']))
    time.sleep(1.5)
len(to_check)
# Out:
# DONE FIXING DISTRICTS
# (0, 29)
# 0

# %%
#Fixing -1 district
accidents = pd.read_csv(fb.FILES_PATH / 'accidents_weather2025.csv')
district_dict = accidents[accidents.district_code != -1][['district','district_code']].drop_duplicates().set_index('district')['district_code'].to_dict()
district_dict['Esplugues de Llobregat'] = 11
district_dict["l'Hospitalet de Llobregat"] = 12
accidents['district_code'] = accidents['district'].map(district_dict)
accidents['district_code'] = accidents['district_code'].astype(int)
accidents.to_csv(fb.FILES_PATH / f'accidents_weather2025.csv',index=False)

# %%
##Fixing Neighborhood desconegut
unique_neigh = accidents.neighborhood.unique().tolist()
try:
    unique_neigh.remove('Desconegut')
except:
    print("DONE FIXING NEIGHBORHOODS")
unique_neigh = [dis.lower() for dis in unique_neigh]
unknown_hoods = accidents[accidents.neighborhood == 'Desconegut']
print(unknown_hoods.shape)
to_check = []

for idx, row in unknown_hoods.head(10).iterrows():
    print(idx, row['lat'],row['lon'])
    result = safe_reverse_geocode(row['lat'], row['lon'])
    # print(row['street_name'].upper(), result.raw['address'])
    if 'quarter' in result.raw['address']:
        print("QUARTER: ",result.raw['address']['quarter'])
        accidents.loc[idx, 'neighborhood'] = result.raw['address']['quarter'].strip()
    elif 'town' in  result.raw['address']:
        print("TOWN: ",result.raw['address']['town'])
        accidents.loc[idx, 'neighborhood'] = result.raw['address']['town'].strip()
    elif 'city' in result.raw['address']:
        print("CITY: ",result.raw['address']['city'])
        accidents.loc[idx, 'neighborhood'] = result.raw['address']['city'].strip()
    else:
        print("ALARMMMMMMMMMMMMMM",idx)
        to_check.append((idx,result.raw['address']))
    time.sleep(1.5)
len(to_check)
# Out:
# DONE FIXING DISTRICTS
# (0, 29)
# 0

# %%
#recovering street codes
import os
files_folder = '/Users/fcbnyc/Desktop/BarcelonAccidents/'
files = os.listdir(files_folder)
code_df = pd.DataFrame()
for file in files:
    if 'accidents' in file:
        df = fb.read_df(files_folder, file)
        selected_columns = [col for col in df.columns 
                            if 'expedi' in col or 
                            ('codi' in col.lower() and 'carrer' in col.lower())]
        df = df[selected_columns]
        df.columns = ['num_incident','street_code']
        print(df.shape)
        code_df = pd.concat([code_df, df])
        print(code_df.shape)
code_df['num_incident'] = code_df['num_incident'].str.strip()
code_df.to_csv(fb.FILES_PATH / 'street_codes.csv', index =False)
# Out:
# Working with...2022_accidents_gu_bcn.csv
# 2022_accidents_gu_bcn.csv successfully read with utf-8
# (7999, 2)
# (7999, 2)
# Working with...2015_accidents_gu_bcn.csv
# 2015_accidents_gu_bcn.csv successfully read with latin-1
# (10009, 2)
# (18008, 2)
# Working with...2010_accidents_gu_bcn.csv
# 2010_accidents_gu_bcn.csv successfully read with latin-1
# (9056, 2)
# (27064, 2)
# Working with...2014_accidents_gu_bcn.csv
# 2014_accidents_gu_bcn.csv successfully read with latin-1
# (9680, 2)
# (36744, 2)
# Working with...2011_accidents_gu_bcn.csv
# 2011_accidents_gu_bcn.csv successfully read with latin-1
# (8831, 2)
# (45575, 2)
# Working with...2023_accidents_gu_bcn.csv
# 2023_accidents_gu_bcn.csv successfully read with utf-8
# (7724, 2)
# (53299, 2)
# Working with...2020_accidents_gu_bcn.csv
# 2020_accidents_gu_bcn.csv successfully read with utf-8
# (6268, 2)
# (59567, 2)
# Working with...2018_accidents_gu_bcn.csv
# 2018_accidents_gu_bcn.csv successfully read with utf-8
# (9936, 2)
# (69503, 2)
# Working with...2025_accidents_gu_bcn.csv
# 2025_accidents_gu_bcn.csv successfully read with utf-8
# (7741, 2)
# (77244, 2)
# Working with...2012_accidents_gu_bcn.csv
# 2012_accidents_gu_bcn.csv successfully read with latin-1
# (9253, 2)
# (86497, 2)
# Working with...2017_accidents_gu_bcn.csv
# 2017_accidents_gu_bcn.csv successfully read with utf-8
# (10339, 2)
# (96836, 2)
# Working with...2013_accidents_GU_bcn.csv
# 2013_accidents_GU_bcn.csv successfully read with latin-1
# (9457, 2)
# (106293, 2)
# Working with...2016_accidents_gu_bcn.csv
# 2016_accidents_gu_bcn.csv successfully read with utf-8
# (10140, 2)
# (116433, 2)
# Working with...2019_accidents_gu_bcn.csv
# 2019_accidents_gu_bcn.csv successfully read with utf-8
# (10027, 2)
# (126460, 2)
# Working with...2021_accidents_gu_bcn.csv
# 2021_accidents_gu_bcn.csv successfully read with utf-8
# (7659, 2)
# (134119, 2)
# Working with...2024_accidents_gu_bcn.csv
# 2024_accidents_gu_bcn.csv successfully read with utf-8
# (7536, 2)
# (141655, 2)

# %%
#Example usage in a loop
coordinates = [coor]
for lat, lon in coordinates:
    result = safe_reverse_geocode(lat, lon)
    print(result,'+++++++++','\n', result[0].split(',')[1])   
    
    # CRITICAL: Sleep for 1+ seconds to respect the usage policy
    time.sleep(1.5)

for corr in pending_acc.iterrows():
    print(corr)

# %%
##Printing data points
df = data[data.code == 701414]

# 2. Create the base map centered on Barcelona (Lat: 41.3851, Lon: 2.1734)
barcelona_map = folium.Map(
    location=[41.3851, 2.1734], 
    zoom_start=13, 
    tiles='OpenStreetMap'
)

# 3. Add markers to the map
for index, row in df.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=(row['street'],row['lon']), # Text displayed when the marker is clicked
        tooltip='Click to see name', # Text displayed when hovering
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(barcelona_map)

# 4. Save and display the map
barcelona_map.save('barcelona_map.html')
# To display in a Jupyter Notebook, simply type: barcelona_map
barcelona_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67b69c0fac8ba27473e7c4181657a442 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67b69c0fac8ba27473e7c4181657a442&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67b69c0fac8ba27473e7c4181657a442 = L.map(
#                 &quot;map_67b69c0fac8ba27473e7c4181657a442&quot;,
#                 {
#                     center: [41.3851, 2.1734],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a7c52f5a413ea416def068261438b0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a7c52f5a413ea416def068261438b0a.addTo(map_67b69c0fac8ba27473e7c4181657a442);
#
#
#             var marker_f38579963fef5733d0c6d2a4deafa847 = L.marker(
#                 [41.4047012788959, 2.1888562879092],
#                 {
# }
#             ).addTo(map_67b69c0fac8ba27473e7c4181657a442);
#
#
#             var icon_200d828b66128942d033a570d32a18ea = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1c5e00589361bc8926711cb93ce268f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7c970d3884de7cf14114a5e7fe3c9f2 = $(`&lt;div id=&quot;html_b7c970d3884de7cf14114a5e7fe3c9f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;C-31&#x27;, 2.1888562879092)&lt;/div&gt;`)[0];
#                 popup_1c5e00589361bc8926711cb93ce268f4.setContent(html_b7c970d3884de7cf14114a5e7fe3c9f2);
#
#
#
#         marker_f38579963fef5733d0c6d2a4deafa847.bindPopup(popup_1c5e00589361bc8926711cb93ce268f4)
#         ;
#
#
#
#
#             marker_f38579963fef5733d0c6d2a4deafa847.bindTooltip(
#                 `&lt;div&gt;
#                      Click to see name
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f38579963fef5733d0c6d2a4deafa847.setIcon(icon_200d828b66128942d033a570d32a18ea);
#
#
#             var marker_77da6c81a9ac5cfc1e9f750dd7bbab0c = L.marker(
#                 [41.413612350384, 2.20137158084917],
#                 {
# }
#             ).addTo(map_67b69c0fac8ba27473e7c4181657a442);
#
#
#             var icon_132fbc3586bf769e3eeee53ba842076a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_05b0df8307bdd88cf34cfe522f6cf67a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d8392eb255f88c87c8f47feff19b049 = $(`&lt;div id=&quot;html_0d8392eb255f88c87c8f47feff19b049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Corts Catalanes&#x27;, 2.20137158084917)&lt;/div&gt;`)[0];
#                 popup_05b0df8307bdd88cf34cfe522f6cf67a.setContent(html_0d8392eb255f88c87c8f47feff19b049);
#
#
#
#         marker_77da6c81a9ac5cfc1e9f750dd7bbab0c.bindPopup(popup_05b0df8307bdd88cf34cfe522f6cf67a)
#         ;
#
#
#
#
#             marker_77da6c81a9ac5cfc1e9f750dd7bbab0c.bindTooltip(
#                 `&lt;div&gt;
#                      Click to see name
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_77da6c81a9ac5cfc1e9f750dd7bbab0c.setIcon(icon_132fbc3586bf769e3eeee53ba842076a);
#
#
#             var marker_e0518a1a6b0ca6c40b95e097feb93375 = L.marker(
#                 [41.413612350384, 2.20137158084917],
#                 {
# }
#             ).addTo(map_67b69c0fac8ba27473e7c4181657a442);
#
#
#             var icon_c1e06e70f92847128f8593978a10573a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_642a603d93a0fd071bcedbe4127336da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1054e784c1ccbb382424a787042f03e7 =
